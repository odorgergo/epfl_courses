# %%
import pandas as pd
from networkx.readwrite import json_graph
import json
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
courses=pd.read_csv("Course_Info.csv")
courses.loc[6].Content_EN
# Out:
# '&lt;p&gt;The course<comma/> obeying a logic of history<comma/> visit construction sites of great civilizing currents from Pharaonic Egypt to the late Middle Ages. It is distributed as follows:&lt;/p&gt;\n&lt;ol&gt;\n&lt;li&gt;Genesis of stone architecture      in Egypt from the third millennium. Development during this time      fundamental<comma/> technical and mathematical knowledge<comma/> allowing the building      of monuments where structural stability<comma/> corresponding to the control of      mechanical stringent rules to ensure their preservation until today<comma/>      doubles as a geometric knowledge to put for harmonious morphology.&lt;/li&gt;\n&lt;li&gt;Aegean world<comma/> from Minoan Crete      to the Hellenistic period. If some knowledge of Greek is derived from the      Egyptian and Mesopotamian heritage<comma/> st&amp;#233;r&amp;#233;otomique perfectionism builders      of Pericles<comma/> is a peak in the rigor of the stone work. On the other hand<comma/>      the birth of democracy<comma/> plays a fundamental role in the new composition of      the city and in the invention of groundbreaking public programs available      to citizens.&lt;/li&gt;\n&lt;li&gt;If Rome provides overwhelming      image of an excessive architectural civilization<comma/> it owes much to the      concern with which the Romans have taken part of the legacy left by the      Greeks. Without inventors Romans knew<comma/> with a remarkable opportunity<comma/>      reproduce and develop technical inventions and programs designed by the      people they had conquered territories. In the Roman town<comma/> so close to ours      that the mind is disturbed<comma/> collective facilities such as private      achievements<comma/> offered residents amenities of convenience<comma/> comfort and even luxury<comma/> in a quiet that no society had known and that Europe took centuries to recover.&lt;/li&gt;\n&lt;li&gt;The renaissance is not to be at      the XV<comma/> but with the return to political stability in Europe from the      eleventh century. Without neglecting the memory of Roman techniques      transmitted despite centuries of unrest<comma/> the architects of the Middle Ages      will re-invent the architecture<comma/> leading to the prodigious Gothic      slenderness upward challenge that a designer engineer boldness of up the      limits of material strength and reaching<comma/> in the nave of the cathedral<comma/> to      abolish the walls<comma/> which he substitutes point supports separated by glass<comma/>      while raising the arches on the borders of a material firmament<comma/> visible      and inaccessible.&lt;/li&gt;\n&lt;/ol&gt;'

# %%
enrollments=pd.read_csv("DataJamDays.csv",encoding="latin9")
enrollments.head(10)
# Out:
#                   CourseEnrolmentID                          PersonID  \
# 0  b85dac3e4d3c0bc00d9c2c1aaa9484c0  58e958ea4531b5624c0a827ed0b139ce
# 1  d43b5e8337f6e03c8100c5c82421b86f  ae7eb0574297b5e692272779cd2f6fa0
# 2  5052837b6d6131783b2ba31a99cbc267  43bd48d5f43035da625c4db1945307b2
# 3  3e130ec4929c9cadf47101b80a312d22  6d1316f513268449837932316ea0d696
# 4  ac934bb9779ca8f1aef06fdd2a214914  f3562b61dc25a46c900bd0b2d078cc91
# 5  0725d86cbd3fc2221669c9b7d72473f6  d404d2d5e7c2fefb80654c0ae18a3118
# 6  62d82ef649b015256141acb863d7792b  91d69aea6b773c3f881f6192340f9065
# 7  212aef09c131b101fb04c47f608a25b6  9ba53a64dbbff21be2bcbb27acc2f433
# 8  13326c29c50bb2b9540212c7e47df95d  b63ebcdfe65c4642e378ced728a17799
# 9  49cfcad64dba604a4399799239e4df22  83700542d878b540a0b8dd6cb49e574d
#
#                           SubjectID   YearName       SemesterName  \
# 0  62918990845509bd69e684af98230cf2  2007-2008  Master semestre 1
# 1  62918990845509bd69e684af98230cf2  2007-2008  Master semestre 1
# 2  62918990845509bd69e684af98230cf2  2007-2008  Master semestre 1
# 3  62918990845509bd69e684af98230cf2  2007-2008  Master semestre 1
# 4  62918990845509bd69e684af98230cf2  2007-2008  Master semestre 1
# 5  62918990845509bd69e684af98230cf2  2007-2008  Master semestre 3
# 6  62918990845509bd69e684af98230cf2  2007-2008  Master semestre 1
# 7  62918990845509bd69e684af98230cf2  2007-2008  Master semestre 1
# 8  62918990845509bd69e684af98230cf2  2007-2008  Master semestre 1
# 9  62918990845509bd69e684af98230cf2  2007-2008  Master semestre 1
#
#          Session SubjectName LevelName TeachingLanguage StudyDomain  \
# 0  Session hiver  Optics III    Master          anglais     Physics
# 1  Session hiver  Optics III    Master          anglais     Physics
# 2  Session hiver  Optics III    Master          anglais     Physics
# 3  Session hiver  Optics III    Master          anglais     Physics
# 4  Session hiver  Optics III    Master          anglais     Physics
# 5  Session hiver  Optics III    Master          anglais     Physics
# 6  Session hiver  Optics III    Master          anglais     Physics
# 7  Session hiver  Optics III    Master          anglais     Physics
# 8  Session hiver  Optics III    Master          anglais     Physics
# 9  Session hiver  Optics III    Master          anglais     Physics
#
#   CourseCodes
# 0    PHYS-449
# 1    PHYS-449
# 2    PHYS-449
# 3    PHYS-449
# 4    PHYS-449
# 5    PHYS-449
# 6    PHYS-449
# 7    PHYS-449
# 8    PHYS-449
# 9    PHYS-449

# %%
def read_json_file(filename):

# %%
with open("graph.json") as f:
    js_graph = json.load(f)
js_graph["links"]=js_graph["edges"]
G=json_graph.node_link_graph(js_graph)
